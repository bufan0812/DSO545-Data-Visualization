# %% [markdown]
# <p style="text-align: center;"> <span style="color:firebrick"> <font size="5"> <b> USC Marshall School of Business </b> </font> </p> </span>
#
# <p style="text-align: center;"> <b> <font font size="5"> DSO 545- Homework 2 </p> </b></font>
#
# <p style="text-align: center;"> <b> Fall 2020 </b> </p>

# %% [markdown]
# ## <span style="color:blue">  Bufan Wang </span>

# %% [markdown]
# ## <span style="color:firebrick">  Assignment Learning Objectives </span>
#
# 1. Read CSV files into Python using `pandas` Python package.
# 2. Explore the data using univariate numerical summaries.
# 3. Explore the data using univariate visual summaries using `seaborn` Python package.
# 4. Collect facts from the dataset

# %% [markdown]
# ## <span style="color:firebrick"> Dataset </span>
#
# The dataset consists of 29 variables. Most of the variable names are self explanatory. The following are some of the variables that might need some clarification:
#
# |**Variables**    |**Explanation**|
# |:-----------------|:--------------|
# |`NumCompaniesWorked`| number of companies worked at before IBM
# |`OverTime`| does the employee work overtime?
# |`PerformanceRating`| employee's last year performance rating
# |`TotalWorkingYear` | number of years the employee has been in the workforce
# |`WorkLifeBalance`| employees rated themselves on their work like balance
# |`YearsInCurrentRole`| years in current role
# |`YearsWithCurrManager` | years with current manager

# %% [markdown]
# ## <span style="color:firebrick"> Assignment Description </span>

# %% [markdown]
# ### HR Employee Attrition
#
# Top tech companies are now fighting for talent among each other. It is important for the HR departments to identify the reasons that attract employees to stay with them or to leave them.
#
# In this assignment, we will apply **univariate EDA** on a hypothetical dataset released by IBM's data scientist for the data science community on IBM's HR attrition.
#
# You are expected to perform both **numerical** and **visual** univariate summaries, and come up with key facts and insights from the dataset.

# %% [markdown]
# ## <span style="color:firebrick"> Grading & Expectations </span>

# %% [markdown]
# - The total number of points for this homework is 10 points
# - Use this Jupyter Notebook as a template and add your answers to it
# - Upload your answers back to blackboard
#
# **Rubrics**
#
#
# |**Grade**    |**Expectation**|
# |:------------|:--------------|
# |**10**       | Full numerical and visual analysis for all variables with facts collected from the data
# |**7 or below** | Full/partial numerical and visual analysis for variables with no facts
# |**6 or below** | partial numerical and visual analysis for variables with no facts

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
HR = pd.read_csv("HR.csv")
HR.info()
HR.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   DailyRate                1470 non-null   int64
#  4   Department               1470 non-null   object
#  5   DistanceFromHome         1470 non-null   int64
#  6   Education                1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   EmployeeCount            1470 non-null   int64
#  9   EmployeeNumber           1470 non-null   int64
#  10  EnvironmentSatisfaction  1470 non-null   int64
#  11  Gender                   1470 non-null   object
#  12  HourlyRate               1470 non-null   int64
#  13  JobInvolvement           1470 non-null   int64
# ...

# %% [markdown]
# ### Numerical EDA

# %%
HR.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
HR['Age'].value_counts()
# Out:
# 35    78
# 34    77
# 31    69
# 36    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 46    33
# 44    33
# 43    32
# 50    30
# 24    26
# 25    26
# 47    24
# 49    24
# 55    22
# 48    19
# 51    19
# 53    19
# 52    18
# 54    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
HR.median()
# Out:
# Age                           36.0
# DailyRate                    802.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeNumber              1020.5
# EnvironmentSatisfaction        3.0
# HourlyRate                    66.0
# JobInvolvement                 3.0
# JobLevel                       2.0
# JobSatisfaction                3.0
# MonthlyIncome               4919.0
# MonthlyRate                14235.5
# NumCompaniesWorked             2.0
# PerformanceRating              3.0
# TotalWorkingYears             10.0
# WorkLifeBalance                3.0
# YearsAtCompany                 5.0
# YearsInCurrentRole             3.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
round(HR['Attrition'].value_counts(normalize = True)*100)
# Out:
# No     84.0
# Yes    16.0
# Name: Attrition, dtype: float64

# %%
round(HR['BusinessTravel'].value_counts(normalize = True)*100)
# Out:
# Travel_Rarely        71.0
# Travel_Frequently    19.0
# Non-Travel           10.0
# Name: BusinessTravel, dtype: float64

# %%
round(HR['Department'].value_counts(normalize = True)*100)
# Out:
# Research & Development    65.0
# Sales                     30.0
# Human Resources            4.0
# Name: Department, dtype: float64

# %%
round(HR['Education'].value_counts(normalize = True)*100)
# Out:
# 3    39.0
# 4    27.0
# 2    19.0
# 1    12.0
# 5     3.0
# Name: Education, dtype: float64

# %%
round(HR['EducationField'].value_counts(normalize = True)*100)
# Out:
# Life Sciences       41.0
# Medical             32.0
# Marketing           11.0
# Technical Degree     9.0
# Other                6.0
# Human Resources      2.0
# Name: EducationField, dtype: float64

# %%
round(HR['EnvironmentSatisfaction'].value_counts(normalize = True)*100)
# Out:
# 3    31.0
# 4    30.0
# 2    20.0
# 1    19.0
# Name: EnvironmentSatisfaction, dtype: float64

# %%
round(HR['Gender'].value_counts(normalize = True)*100)
# Out:
# Male      60.0
# Female    40.0
# Name: Gender, dtype: float64

# %%
round(HR['JobInvolvement'].value_counts(normalize = True)*100)
# Out:
# 3    59.0
# 2    26.0
# 4    10.0
# 1     6.0
# Name: JobInvolvement, dtype: float64

# %%
round(HR['JobLevel'].value_counts(normalize = True)*100)
# Out:
# 1    37.0
# 2    36.0
# 3    15.0
# 4     7.0
# 5     5.0
# Name: JobLevel, dtype: float64

# %%
round(HR['JobSatisfaction'].value_counts(normalize = True)*100)
# Out:
# 4    31.0
# 3    30.0
# 1    20.0
# 2    19.0
# Name: JobSatisfaction, dtype: float64

# %%
HR['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
round(HR['JobRole'].value_counts(normalize = True)*100)
# Out:
# Sales Executive              22.0
# Research Scientist           20.0
# Laboratory Technician        18.0
# Manufacturing Director       10.0
# Healthcare Representative     9.0
# Manager                       7.0
# Sales Representative          6.0
# Research Director             5.0
# Human Resources               4.0
# Name: JobRole, dtype: float64

# %%
round(HR['MaritalStatus'].value_counts(normalize = True)*100)
# Out:
# Married     46.0
# Single      32.0
# Divorced    22.0
# Name: MaritalStatus, dtype: float64

# %%
round(HR['NumCompaniesWorked'].value_counts(normalize = True)*100)
# Out:
# 1    35.0
# 0    13.0
# 3    11.0
# 2    10.0
# 4     9.0
# 7     5.0
# 6     5.0
# 5     4.0
# 9     4.0
# 8     3.0
# Name: NumCompaniesWorked, dtype: float64

# %%
round(HR['OverTime'].value_counts(normalize = True)*100)
# Out:
# No     72.0
# Yes    28.0
# Name: OverTime, dtype: float64

# %%
round(HR['PerformanceRating'].value_counts(normalize = True)*100)
# Out:
# 3    85.0
# 4    15.0
# Name: PerformanceRating, dtype: float64

# %%
round(HR['WorkLifeBalance'].value_counts(normalize = True)*100)
# Out:
# 3    61.0
# 2    23.0
# 4    10.0
# 1     5.0
# Name: WorkLifeBalance, dtype: float64

# %% [markdown]
# ### Visual EDA

# %%
sns.distplot(HR['Age'])

# %%
sns.boxplot(data = HR, x = 'Age')

# %%
sns.countplot(data = HR, x = 'Attrition')

# %%
sns.countplot(data = HR, x = 'BusinessTravel')

# %%
sns.distplot(HR['DailyRate'])

# %%
sns.boxplot(data = HR, x = 'DailyRate',color = 'pink')

# %%
sns.countplot(data = HR, x = 'Department')

# %%
sns.distplot(HR['DistanceFromHome'],color = 'pink')

# %%
sns.boxplot(data = HR, x = 'DistanceFromHome',color = 'pink')

# %%
sns.countplot(data = HR, x = 'Education')

# %%
sns.countplot(data = HR, x = 'EducationField')

# %%
sns.distplot(HR['EmployeeNumber'])

# %%
sns.countplot(data = HR, x = 'EnvironmentSatisfaction',)

# %%
sns.distplot(HR['HourlyRate'])

# %%
sns.boxplot(data = HR, x = 'HourlyRate')

# %%
sns.countplot(data = HR, x = 'Gender')

# %%
sns.countplot(data = HR, x = 'JobInvolvement')

# %%
sns.countplot(data = HR, x = 'JobLevel')

# %%
sns.countplot(data = HR, x = 'JobRole')

# %%
sns.countplot(data = HR, x = 'MaritalStatus')

# %%
sns.distplot(HR['MonthlyIncome'])

# %%
sns.boxplot(data = HR, x = 'MonthlyIncome')

# %%
sns.distplot(HR['MonthlyRate'])

# %%
sns.boxplot(data = HR, x = 'MonthlyRate')

# %%
sns.countplot(data = HR, x = 'NumCompaniesWorked')

# %%
sns.countplot(data = HR, x = 'OverTime')

# %%
sns.countplot(data = HR, x = 'PerformanceRating')

# %%
sns.distplot(HR['TotalWorkingYears'])

# %%
sns.boxplot(data = HR, x = 'TotalWorkingYears')

# %%
sns.countplot(data = HR, x = 'WorkLifeBalance')

# %%
sns.distplot(HR['YearsAtCompany'])

# %%
sns.boxplot(data = HR, x = 'YearsAtCompany')

# %%
sns.distplot(HR['YearsInCurrentRole'])

# %%
sns.boxplot(data = HR, x = 'YearsInCurrentRole')

# %%
sns.distplot(HR['YearsSinceLastPromotion'])

# %%
sns.boxplot(data = HR, x = 'YearsSinceLastPromotion')

# %%
sns.distplot(HR['YearsWithCurrManager'])

# %%
sns.boxplot(data = HR, x = 'YearsWithCurrManager')

# %% [markdown]
# # Insights

# %% [markdown]
# ## Age
#
# - The Age variable has a mean of 40, median of 36, maximun of 60,minimum of 18, and std of 9.13.
# - The distribution is right skewed, with no outliers.
# - 50% of employees have age between 30 and 43.
# - 25% of employees have age under 30.
# - 25% of employees have age above 43.
#
# ## Attrition
#
# - There are 16% of employees who have left their companies and 84% of employees who still work for their companies.
#
# ## BusinessTravel
#
# - 71% of employees rarely travel, 19% of employees travel frequently, and 10% of employees do not travel.
#
# ## DailyRate
#
# - The mean of employees' daily rate is 802, median is 802, minimum is 102, maximum is 1499, and std is 403.
# - The DailyRate variable is nearly symmetrical distributed and is evenly distributed.
# - 50% of employees have daily rate between 465 and 1157.
# - 25% of employees have daily rate under 465.
# - 25% of employees have daily rate above 1157.
# - There are no outliers.
#
# ## Department
#
# - 65% of employees are in department of Research & Development, 30% of employees are in department of Sales, and only 5% of employees are in department of Human Resources.
#
# ## DistanceFromHome
#
# - The variable DistanceFromHome has mean of 9.19, median of 7, maximum of 29, and minimum of 1.
# - The variable is right skewed.
# - 50% of distance from home to work of employees are between 2 miles and 14 miles.
# - 25% of distance are under 2 miles.
# - 25% of distance are above 14 miles.
# - There are no outliers.
#
# ## Education
#
# - On average, employees have 3 years of education, with median of 3, std of 1, minimum of 1, and maximum of 5.
# - 39% of employees have 3 years of education, 27% of employees have 4 years of education, 19% of employees have 2 years of education, 12% of employees have 1 years of education, and only 3% of employees have 5 years of education.
#
# ## EducationField
#
# - Employees with an education field in Life Science (41%) and Medical(32%) combined to represent 73% of the samply. 11% of employees with an education field in Marketing. Employees from Technical Degree, Other, and Human Resources combined to represent 17% of population.
#
# ## EmployeeCont
#
# - No meaningful insights can be gained from this variable.
#
# ## EmployeeNumber
#
# - No meaningful insights can be gained from this variable, as this variable only represents the identity of each employee.
# - The mean is 1025, the median is 1020, the maximun is 2068, the minimum is 1.
#
# ## EnvironmentSatisfaction
#
# - On average, employees rate the working environment as 2.7 (scale 1-4), median is 3.
# - 60% of employees, who rated 4 or 3, think the working environment is great, 20% of employees, who rated 2, think the working environment is decent, 20% of employees think the working environment is bad and give a rate of 1.
#
# ## Gender
#
# - 60% of employees are male, and 40% of employees are female.
#
# ## HourlyRate
#
# - The variable HourlyRate has a mean of 66, median of 66,maximum of 100, minimum of 30, and std of 20.
# - The variable is symmetrical distributed.
# - 50% of employees have hourly rate between 48 and 83.75.
# - 25% of employees have hourly rate below 48.
# - 25% of employees have hourly rate above 83.75.
# - There are no outliers.
#
# ## JobInvolvement
#
# - The mean is 2.7, the median is 3, the maximum is 4, the minimum is 1, and the std is 0.71.
# - 10% of employees rate their job involvement as high,59% of employees rate their job involvement as above average. 25% of employees rate their job involvement as medium (2 out of 4). 6% of employees think their job involvement is low.
#
# ## JobLevel
#
# - The mean job level is 2.06 (scale of 1-5), median is 2, and std is 1.1
# - 73% of employees have entry-level job (level 1 or 2), 15% of employees have medium-level job (level 3), and 12% of employees have high-level job (level 4 or 5).
#
# ## JobSatisfaction
#
# - The mean job satisfaction is 2.7 (scale of 1-4), median is 3, and std is 1.1
# - 31% of employees are very satisfied with their job, 30% of employees think their jobs are above average, 19% of employees think their jobs are below average, and 20% of employees are not satisfied with their job.
#
# ## JobRole
#
# - 60% of employees are Sales Executive (22%), Research Scientist (20%), and Laboratory Technician (18%).
# - 10% of employees are Manufacturing Director, and 9% are Healthcare Representative.
# - Manager, Sales Representative, research Director, and Human Resources combined to represent 21% of employees.
#
# ## MaritalStatus
#
# -  46% of employees are married, 32% are single, and 22% are divorced.
#
# ## MonthlyIncome
#
# - The average monthly income is 6503, median is 4919, maximum is 19999, minimum is 1009, and std is 4708.
# - The variable is right skewed.
# - 50% of employees have monthly income between 2911 and 8379.
# - 25% of employees have monthly income below 2911, and 25% have monthly income above 8379.
# - There are many outliers (those employees who have income higher than 17000.
#
# ## MonthlyRate
#
# - The average monthly rate is 14313, median is 14235, maximum is 26999, minimum is 2094, and std is 7117.
# - The variable is symmetrical distributed.
# - 50% of employees have monthly rate between 8047 and 20461.
# - 25% of employees have monthly rate under 8047, and 25 % have montnly rate above 20461.
# - There are no outliers.
#
# ## NumCompaniesWorked
#
# - On average, employees have worked for 2.7 companies before working at current company. Minimum is 0 and maximum is 9, median is 2, and std is 2.5.
# - 35% of employees have worked for 1 company before and represent the biggest employee population.
# - 13% of employees have worked for 0 company before
# - 12% of employees have worked for 3 companies before
# - 10% of employees have worked for 2 companies before
# - 30% of employees have worked for at least 4 companies before
#
# ## OverTime
#
# - 28% of employees have worked over time
# - 72% of employees haven't worked over time
#
# ## PerformanceRating
#
# - 85% of employees rated as 3 based on last year's performance
# - 15% of employees rated as 4 based on last year's performance
#
# ## TotalWorkingYears
#
# - On average, employees have worked for 11.2 years in total. The median is 10, maximum total working year is 40, minimum is 0, and std is 7.78.
# - The variable is right skewed.
# - 50% of employees have worked for years between 6 and 15.
# - 25% of employees have worked for years under 6, and 25% of employees have worked for years above 15.
# - There are some outliers (those who worked above 26 years.
#
# ## WorkLifeBalance
#
# - On a scale of 1-4, 61% of employees rate their work life balance as 3, 10% of employees rate their work life balance as 4. Combined, 71% of employees are satisifed with their work life balance. 23% of employees rate their work life balance as 2, and 6% rate their work life balance as 1. Combined, 29% of employees are not satisfied with their work life balance.
#
# ## YearsAtCompany
#
# - On average, employees have spent 7 years at IBM. Median is 5, maximum years is 40, minimum is 0, and std is 6.1.
# - The variable is right skewed. Most of employees have spent less than 10 years at IBM.
# - 50% of employees have spent years at IBM between 3 and 9.
# - 25% of employees have spent years at IBM under 3 years, and 25% above 9 years.
# - There are some outliers (those who have worked at IBM for more than 17 years.
#
# ## YearsInCurrentRole
#
# - On average, employees have spent 4.2 years on their current role. Median is 3, maximum is 18,minimum is 0, and std is 3.6.
# - The variable is right skewed. Most employees have spent years on their current role between 0 and 10 years.
# - 50% of employees have spent years on their current role between 2 years and 7 years.
# - 25% of employees have spent years on their current role for less than 2 years, 25% have spent for more than 7 years.
# - There are some outliers (those who have worked for their current role for 13 years.
#
# ## YearsSinceLastPromotion
#
# - On average, it has been 2.1 years since employees get promoted at IBM. The median years is 1, maximum is 15, minimum is 0, and std is 3.2
# - The variable is right skewed. Most people get promoted last year and the year before last year.
# - 50% of employees get promoted between 0 and 3 years ago.
# - 25% of employees get promoted last years, 25% of employees get promoted at last 3 years ago.
# - There are some outlies (thouse who get promoted at least 7 years ago.
#
# ## YearsWithCurrManager
#
# - On average, employees have spent 4.1 years with their current managers. The median years is 3 years, maximum is 17 years, minimum is 0 , and std is 3.6.
# - The variable is right skewed. Most employees have spent less than 10 years with their current manager.
# - 50% of employees have spent years between 03 and 7 years with their current manager.
# - 25% of employees have spent years under 2 years with their current manager, and 25% of employees have spent years above 7 years.
# - There are some outliers (those who have spent more than 13 years with their current manager).
