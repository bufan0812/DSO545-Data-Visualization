# %% [markdown]
# # Cardio GoodFitness Insights

# %% [markdown]
# ## Univatiate Analysis:
#
# ##### Age
#
# - Age is right skewed and it ranges between approximately 20 and 50. Most of the ages are between 20 and 30 with a peak at 25.
# - The median of age is 26, meaning that 50% of people have age greater than 26, vice versa.
# - 50% of people have age between 23 and 33
# - 25& of people have age under 23, 25% of people have age above 33
# - There are some outliers that are above 46.
#
#
# ##### Income
#
# - Income is right skewed and it ranges between approximately 30K and 100K. Most of the incomes are between btween 30K and 60K with a peak around 40K.
# - Income has a median that is around 50k, meaning that 50% of people have income that is below 50k, vice versa.
# - 50% of people have income between 45k and 60k
# - 25% of people have income below 45k, 25% have income above 60k
# - There are some people that have outlier income that are above 80k.
#
# ##### Miles
#
# - Miles is also right skewed and it ranges between approximately 20 and 400. Most of the distances are between btween 50 and 110 miles with a peak around 80 miles.
# - The median is around 90, meaning that 50% of people expect to walk more that 90 miles per week.
# - 50% of people expect to walk between 60 and 130 miles per week
# - 25% of people expect to walk under 60, and 25% of people expect to walk above 130.
# - There are some people that have outlier miles that are above 180 miles.
#
#
# ##### Product
#
# - Thre are three products: TM195, TM498, TM798.
# - TM195 is the most popular, and TM798 is the least popular.
# - The TM195 sells twice TM798
# - There was 44t% TM195 customer, 33% TM498 customer, 22% TM798 customer.
#
# ##### Gender
# - There were 58% male customers, 42% female customers.
# - There were more male than female in this customer sample.
#
#
# ##### Education
# - Customers have 16 years of education represent the most customer group(47%), followed by those who have 14 years of education (31%) and 18 years of education (13%)
# - The company did not sell to much product to customers with 12,13,15,20,and 21 years of education, all of which combined to represent only 11% of sample.
#
#
#
# ##### Usage
#
# - Customers who use the product 3 times a week represent the most (38%) followed by customers who use 4 times a week (29%) and 2 times a week (18%)
#
# - Customers who use the product 5,6,7 times a week combined to represent 14% of the customer sample.
#
#
# ##### Fitness
#
# - Customers who rated their fitness as average (3) represent 54% of the sample.
# - 30% of customers rated their fitness as high (4-5).
# - Only 15% of customers rated their fitness as low (1-2).
#
#
#
# ## Bivariate Analysis:
#
#
# ##### Product x Age
#
# - Product TM798 are mainly used by customers at age 23-37, with some outliers (age above 37).
# - The median of Product TM798 is higher than that of TM195 and TM498, both of which are approximately the same
# - The median of all products are around 25.
#
#
# ##### Product x Income
#
# - Generally, customers who bought TM798 have higher income than customers who bought the other two products.
# - Customers who have income less than 70k tend to purchase TM195 & TM498
#
# ##### Product x Miles
#
# - People expect them to walk more miles tend to buy product TM798.
# - On average, people using product TM798 are expected to walk more miles than people using the other two product.
# - Customers who bought TM195 & TM498 are expected to work less than 140 miles/week.
#
# ##### Fitness x Age
#
# - Customers who rated themselves very low on fitness are mostly at their 20's.
# - Customers who rated themselves '1' on fitness are mostly ages 23-30.
# - There are some customers who are at their 20's but rated themselves high on fitness.
#
# #####  Fitness x Income
#
# - Customers who have high income rated themselves high (5) on fitness.
# - Most customers who rated their fitness as 1-4 have income below 70k.
# - Customers who rated their fitness as 5 have median that is much higher than that of customers who rated their fitness as 1-4.
#
#
# ##### Fitness x Miles
#
# - There is a clear positive relationship between people's expected level of fitness and the number of miles that customers expected to walk.
#
#
# ##### Age x Miles
#
# - There is no clear pattern between age and miles.
# - Most customers expect to walk under 200 miles/week.
#
#
# ##### Age x Income
#
# - There is a clear positive relationship between age and income, as expected.
# - Customers have ages concentrated between 20 and 30 and have incomes between 30-55.
#
# ##### Gender x Miles x Product
# - On average, male and female customers expect to walk around the same miles for product TM498 and TM195.
# - On average, female customers using TM798 expect to walk more miles than male customers using the same product.
#
# ##### Age x Gender x Income
# - Positive linear relationship between Age and Income for both male and female customers.
# - On average, male has higher income than female customers.
#
# ##### Age x Gender x Income x Product
# - Customers who are using TM798 tend have higher income.
# - Among customers of TM798, there are much more male than female customers. Also, male customers tend to have higher     income.
